# %%
# SL(2,C) dönüşümlerini yapıp, objeleri güncellemek (eski halinde güncellenmiyordu).

# Paketi yükleyelim:

reset()
load("NPDerivatives.sage")

# %%
# Her şeyin şu anki halini görelim:
showall()
# Out:
# 'alpha=' alpha
# 'beta=' beta
# 'epsilon=' epsilon
# 'gamma=' gamma
# 'kappa=' kappa
# 'mu=' mu
# 'nu=' nu
# 'pi=' pi
# 'rho=' rho
# 'sigma=' sigma
# 'tau=' tau
# 'lambda=' lambdaa
# 'Phi00=' Phi00
# 'Phi01=' Phi01
# 'Phi02=' Phi02
# 'Phi10=' Phi10
# 'Phi11=' Phi11
# 'Phi12=' Phi12
# 'Phi20=' Phi20
# 'Phi21=' Phi21
# 'Phi22=' Phi22
# 'Lambda=' Lambda
# 'Psi0=' Psi0
# 'Psi1=' Psi1
# 'Psi2=' Psi2
# 'Psi3=' Psi3
# 'Psi4=' Psi4

# %%
# z değişkenini tanımlayalım:
var('z')

# İstersek z'ye değer de verebiliriz. 
# Gülay'dan gelen notta Phi01'i sıfırlamak için aşağıdaki tanım kullanılıyordu (biraz farklıydı):
z=-Phi10/Phi00

# A tipi dönüşüm yapalım:
CKAdo(z)
# Out:
# Null Rotation about l

# %%
# Phi01'in değerini görelim (sıfırlanmış):
Phi01
# Out:
# 0

# %%
# Tüm değerleri görelim (denklemleri de görmek istersek NPeqs() ve Bianchi() komutlarını kullanabiliriz):
showall()
# Out:
# 'alpha=' (Phi00^2*alpha - Phi00*Phi10*epsilon + Phi10^2*kappa - Phi00*Phi10*rho)/Phi00^2
# 'beta=' (Phi00^2*beta - Phi00*Phi01*epsilon + Phi01*Phi10*kappa - Phi00*Phi10*sigma)/Phi00^2
# 'epsilon=' (Phi00*epsilon - Phi10*kappa)/Phi00
# 'gamma=' -(Phi00^2*Phi01*alpha + Phi00^2*Phi10*beta - Phi00*Phi01*Phi10*epsilon - Phi00^3*gamma + Phi01*Phi10^2*kappa - Phi00*Phi01*Phi10*rho - Phi00*Phi10^2*sigma + Phi00^2*Phi10*tau)/Phi00^3
# 'kappa=' kappa
# 'mu=' -(2*Phi00^2*Phi10*beta - 2*Phi00*Phi01*Phi10*epsilon + Phi01*Phi10^2*kappa - Phi00^3*mu + Phi00^2*Phi01*pi - Phi00*Phi10^2*sigma - Phi00*Phi01*Dl(Phi10) + Phi00^2*Dm(Phi10) + (Phi01*Dl(Phi00) - Phi00*Dm(Phi00))*Phi10)/Phi00^3
# ...

# %%
# Bunun üstüne bir B tipi dönüşüm yapalım (üst üste istediğimiz kadar dönüşüm yapabiliriz)
# z yerine y değişkeni kullanalım (her üst üste dönüşümde ayrı değişken kullanalım):
var('y',domain='complex')

var('A,theta',domain='real')

y=sqrt(A)*exp(I*theta/2)

CKBdo(y)
# Out:
# Boost in l-n Plane and Spatial Rotation in m-mbar Plane

# %%
# Phi02'ye bakalım:
show(Phi12)
# Out:
# -(2*Phi00*Phi01*Phi11*e^(I*theta) - Phi00^2*Phi12*e^(I*theta) - (2*Phi01^2*e^(I*theta) - Phi00*Phi02*e^(I*theta))*Phi10)/(Phi00^2*conjugate(sqrt(A))^2)

# %%
# C tipi dönüşüm yapalım:

var('w',domain='complex')

CKCdo(w)
# Out:
# Null Rotation about n

# %%
# Phi02'ye bakalım:
show(Phi12)
# Out:
# -(2*A*Phi00^2*Phi01*Phi11*e^(I*theta) - A*Phi00^3*Phi12*e^(I*theta) - (2*A*Phi00*Phi01^2*e^(I*theta) - A*Phi00^2*Phi02*e^(I*theta))*Phi10 - (4*Phi00*Phi01*Phi10*Phi11 - 2*Phi00^2*Phi10*Phi12 + Phi00*Phi01^2*Phi20 - 2*Phi00^2*Phi01*Phi21 + Phi00^3*Phi22 - (3*Phi01^2 - Phi00*Phi02)*Phi10^2)*w)/(A*Phi00^3*conjugate(sqrt(A))^2)
